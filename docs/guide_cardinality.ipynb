# %% [markdown]
# # Advanced Cardinality Choice Modeling Guide
#
# [![Binder](https://mybinder.org/badge_logo.svg)](https://mybinder.org/v2/gh/jbussemaker/adsg-core/HEAD?labpath=docs%2Fguide_cardinality.ipynb)
#
# This notebook provides an overview on how to model choices with advanced cardinality, for example:
# - Selection choices with more possibilities than "select 1 of n options"
# - Connection choices that:
#   - Derive target nodes from source nodes
#   - Remove unconnected source/target nodes from the graph
#   - Use these features to provide a more elegant way of modeling advanced selection cardinality choices
#
# Refer to the [theory](../theory) and [guide](guide) for more background information.
#
# For reference, we display all the possible nodes and edges in the DSG here:

# %%
from adsg_core.render import DSGRenderer
DSGRenderer.render_legend()
# Out:
# <div id="807c15f5128843b8b1f442aeb095ddf7"></div>
# <script type="text/javascript" src="https://cdn.jsdelivr.net/npm/@viz-js/viz@3.8.0/lib/viz-standalone.js"></script>
# <script type="text/javascript">
# (function() {
#   var dot = "strict digraph {\nrankdir=LR;\ndpi=60;\nfontsize=16;\nranksep=0;\nnodesep=0.1;\nlabel=\"DSG Legend\";\nlabelloc=t;\nbgcolor=\"#f5f8fa\";\nnode [height=0];\nleg_0 [label=\"Choice 1\", style=\"filled\", fillcolor=\"#81D4FA\", shape=ellipse, margin=0];\nleg_1 [label=\"Choice 2\", style=\"filled\", fillcolor=\"#81D4FA\", shape=ellipse, margin=0];\nleg_2 [label=<<B>Start Node</B>>, style=\"filled,bold\", fillcolor=\"#ffffff\", shape=ellipse, margin=0];\nleg_3 [label=\"Continuous\\nDV  [0 .. 1]\", style=\"filled\", fillcolor=\"#DCE775\", shape=ellipse, margin=0];\nleg_4 [label=\"Discrete\\nDV  [A,B,C]\", style=\"filled\", fillcolor=\"#DCE775\", shape=ellipse, margin=0];\nleg_5 [label=\"Objective [\u2193]\", style=\"filled\", fillcolor=\"#DCE775\", shape=rect, margin=0];\nleg_6 [label=\"Constraint [\u2264 0]\", style=\"filled\", fillcolor=\"#DCE775\", shape=rect, margin=0];\nleg_7 [label=\"Output Metric\", style=\"filled\", fillcolor=\"#DCE775\", shape=rect, margin=0];\nleg_8 [label=\"Source 1\", style=\"filled\", fillcolor=\"#ffffff\", shape=hexagon, margin=0];\nleg_9 [label=\"Connection\\nChoice\", style=\"filled\", fillcolor=\"#81D4FA\", shape=hexagon, margin=0];\nleg_10 [label=\"Target 1\", style=\"filled\", fillcolor=\"#ffffff\", shape=hexagon, margin=0];\nleg_11 [label=\"Target 2\", style=\"filled\", fillcolor=\"#ffffff\", shape=hexagon, margin=0];\nleg_12 [label=\"Source 2\", style=\"filled\", fillcolor=\"#ffffff\", shape=hexagon, margin=0];\nleg_13 [label=\"Source 2\", style=\"filled\", fillcolor=\"#ffffff\", shape=hexagon, margin=0];\nleg_14 [label=\"Source\", style=\"filled\", fillcolor=\"#ffffff\", shape=ellipse, margin=0];\nleg_15 [label=\"Selection\\nChoice\", style=\"filled\", fillcolor=\"#81D4FA\", shape=ellipse, margin=0];\nleg_16 [label=\"Option 1\", style=\"filled\", fillcolor=\"#ffffff\", shape=ellipse, margin=0];\nleg_17 [label=\"Option 2\", style=\"filled\", fillcolor=\"#ffffff\", shape=ellipse, margin=0];\nleg_18 [label=\"Etc...\", style=\"filled\", fillcolor=\"#ffffff\", shape=ellipse, margin=0];\nleg_19 [label=\"E\", style=\"filled\", fillcolor=\"#ffffff\", shape=ellipse, margin=0];\nleg_20 [label=\"F\", style=\"filled\", fillcolor=\"#ffffff\", shape=ellipse, margin=0];\nleg_21 [label=\"C\", style=\"filled\", fillcolor=\"#ffffff\", shape=ellipse, margin=0];\nleg_22 [label=\"D\", style=\"filled\", fillcolor=\"#ffffff\", shape=ellipse, margin=0];\nleg_23 [label=\"A\", style=\"filled\", fillcolor=\"#ffffff\", shape=ellipse, margin=0];\nleg_24 [label=\"B\", style=\"filled\", fillcolor=\"#ffffff\", shape=ellipse, margin=0];\nleg_25 [label=\"Connector\", style=\"filled\", fillcolor=\"#ffffff\", shape=hexagon, margin=0];\nleg_26 [label=\"Node\", style=\"filled\", fillcolor=\"#ffffff\", shape=ellipse, margin=0];\nleg_0 -> leg_1 [color=\"#9C27B0\", style=dotted, penwidth=3, arrowhead=none, label=\"choice\\nconstraint\"];\nleg_2 -> leg_3 [type=\"EdgeType.DERIVES\"];\nleg_2 -> leg_4 [type=\"EdgeType.DERIVES\"];\nleg_2 -> leg_5 [type=\"EdgeType.DERIVES\"];\nleg_2 -> leg_6 [type=\"EdgeType.DERIVES\"];\nleg_2 -> leg_7 [type=\"EdgeType.DERIVES\"];\nleg_8 -> leg_9 [type=\"EdgeType.CONNECTS\", style=dashed, label=\"1\"];\nleg_8 -> leg_10 [type=\"EdgeType.EXCLUDES\", style=dashed, color=red, label=\"connection\\nexcluded\"];\nleg_9 -> leg_10 [type=\"EdgeType.CONNECTS\", style=dashed, label=\"1..* \u2225\"];\nleg_9 -> leg_11 [type=\"EdgeType.CONNECTS\", style=dashed, label=\"0..2\"];\nleg_12 -> leg_9 [type=\"EdgeType.CONNECTS\", style=dashed, label=\"0,1\"];\nleg_13 -> leg_9 [type=\"EdgeType.CONNECTS\", style=dashed, label=\"0..* \u2225\"];\nleg_14 -> leg_15 [type=\"EdgeType.DERIVES\"];\nleg_15 -> leg_16 [type=\"EdgeType.DERIVES\"];\nleg_15 -> leg_17 [type=\"EdgeType.DERIVES\"];\nleg_15 -> leg_18 [type=\"EdgeType.DERIVES\"];\nleg_19 -> leg_20 [label=\"mutually\\nincompatible\", type=\"EdgeType.INCOMPATIBILITY\", color=red, arrowhead=none];\nleg_21 -> leg_22 [label=\"connects to\", type=\"EdgeType.CONNECTS\", style=d ...
#   var printDot = false; // Whether to print the dot instead of rendering
#   var printSvg = false; // Whether to print the SVG instead of showing the results
#   // Create viz-js instance and render to SVG
#   function doRender() {
#     if (printDot) {
#       var preEl = document.createElement('pre');
#       preEl.innerText = dot;
#       document.getElementById("807c15f5128843b8b1f442aeb095ddf7").appendChild(preEl);
#     } else {
#       Viz.instance().then(function(viz) {
#         var tgtEl = document.getElementById("807c15f5128843b8b1f442aeb095ddf7");
#         var svgElement = viz.renderSVGElement(dot);
#         if (printSvg) {
#           var preEl = document.createElement('pre');
#           preEl.innerText = svgElement.outerHTML;
#           tgtEl.appendChild(preEl);
#         } else {
#           tgtEl.appendChild(svgElement);
#         }
#       }).catch(function(e) {
#         console.log('RENDER ERROR', e, dot);
#         var preEl = document.createElement('pre');
#         preEl.innerText = 'RENDER ERROR: '+e.toString();
#         document.getElementById("807c15f5128843b8b1f442aeb095ddf7").appendChild(preEl);
#         var preEl = document.createElement('pre');
#         preEl.innerText = dot;
#         document.getElementById("807c15f5128843b8b1f442aeb095ddf7").appendChild(preEl);
#       });
#     }
#   }
#   // We may need to wait for loading to complete
#   function checkRender() {
#     if (typeof Viz === "undefined") { setTimeout(checkRender, 100+200*Math.random()); } else { doRender(); }
#   }
#   checkRender();
# })()
# </script>

# %% [markdown]
# ## Selection Choices with Advanced-Cardinality
#
# Selection choices can be used to define more advanced cardinality choices than "choose 1 of n", by using derivation edges to derive other options.
#
# For example, to model a "take 2 of 3" scenario, intermediary nodes can be used to define all possible options of selecting 2 of 3 option nodes:

# %%
from adsg_core import BasicDSG, NamedNode

# Create the DSG
dsg = BasicDSG()

# Define the nodes in the set to be selected
nodes_in_set = [NamedNode(f'Node {i}') for i in range(3)]

# Define the distinct options of the selection node, one for each combination of selecting 2 of 3:
# Select nodes 1 and 2, select nodes 1 and 3, or select nodes 2 and 3.
option_nodes = [NamedNode(f'Opt {i}') for i in range(3)]
dsg.add_edges([
    (option_nodes[0], nodes_in_set[0]), (option_nodes[0], nodes_in_set[1]),  # Option 1 selects node 1 and 2
    (option_nodes[1], nodes_in_set[0]), (option_nodes[1], nodes_in_set[2]),  # Option 2 selects node 1 and 3
    (option_nodes[2], nodes_in_set[1]), (option_nodes[2], nodes_in_set[2]),  # Option 3 selects node 2 and 3
])

# Define the selection choice
start_node = NamedNode('Selection')
dsg.add_selection_choice('Select 2 of 3', start_node, option_nodes)

dsg = dsg.set_start_nodes({start_node})

# Show the DSG (also works outside a notebook)
dsg.render()
dsg.render_legend(['NODE', 'NODE_START', 'EDGE_DERIVE', 'CHOICE_SEL'])
# Out:
# <div id="22489a9b6ae14d7baf4868aaab2a2d11"></div>
# <script type="text/javascript" src="https://cdn.jsdelivr.net/npm/@viz-js/viz@3.8.0/lib/viz-standalone.js"></script>
# <script type="text/javascript">
# (function() {
#   var dot = "strict digraph {\nrankdir=LR;\ndpi=60;\nfontsize=20;\n0 [label=\"Opt 0\", style=\"filled\", fillcolor=\"#ffffff\", shape=ellipse, margin=0.05];\n1 [label=\"Node 0\", style=\"filled\", fillcolor=\"#ffffff\", shape=ellipse, margin=0.05];\n2 [label=\"Node 1\", style=\"filled\", fillcolor=\"#ffffff\", shape=ellipse, margin=0.05];\n3 [label=\"Opt 1\", style=\"filled\", fillcolor=\"#ffffff\", shape=ellipse, margin=0.05];\n4 [label=\"Node 2\", style=\"filled\", fillcolor=\"#ffffff\", shape=ellipse, margin=0.05];\n5 [label=\"Opt 2\", style=\"filled\", fillcolor=\"#ffffff\", shape=ellipse, margin=0.05];\n6 [label=<<B>Selection</B>>, style=\"filled,bold\", fillcolor=\"#ffffff\", shape=ellipse, margin=0.05];\n7 [label=\"Select 2 of 3\", style=\"filled\", fillcolor=\"#81D4FA\", shape=ellipse, margin=0.05];\n0 -> 1 [type=\"EdgeType.DERIVES\"];\n0 -> 2 [type=\"EdgeType.DERIVES\"];\n3 -> 1 [type=\"EdgeType.DERIVES\"];\n3 -> 4 [type=\"EdgeType.DERIVES\"];\n5 -> 2 [type=\"EdgeType.DERIVES\"];\n5 -> 4 [type=\"EdgeType.DERIVES\"];\n6 -> 7 [type=\"EdgeType.DERIVES\"];\n7 -> 0 [type=\"EdgeType.DERIVES\"];\n7 -> 3 [type=\"EdgeType.DERIVES\"];\n7 -> 5 [type=\"EdgeType.DERIVES\"];\n}\n"; // Export of the dot graph notation
#   var printDot = false; // Whether to print the dot instead of rendering
#   var printSvg = false; // Whether to print the SVG instead of showing the results
#   // Create viz-js instance and render to SVG
#   function doRender() {
#     if (printDot) {
#       var preEl = document.createElement('pre');
#       preEl.innerText = dot;
#       document.getElementById("22489a9b6ae14d7baf4868aaab2a2d11").appendChild(preEl);
#     } else {
#       Viz.instance().then(function(viz) {
#         var tgtEl = document.getElementById("22489a9b6ae14d7baf4868aaab2a2d11");
#         var svgElement = viz.renderSVGElement(dot);
#         if (printSvg) {
#           var preEl = document.createElement('pre');
#           preEl.innerText = svgElement.outerHTML;
#           tgtEl.appendChild(preEl);
#         } else {
#           tgtEl.appendChild(svgElement);
#         }
#       }).catch(function(e) {
#         console.log('RENDER ERROR', e, dot);
#         var preEl = document.createElement('pre');
#         preEl.innerText = 'RENDER ERROR: '+e.toString();
#         document.getElementById("22489a9b6ae14d7baf4868aaab2a2d11").appendChild(preEl);
#         var preEl = document.createElement('pre');
#         preEl.innerText = dot;
#         document.getElementById("22489a9b6ae14d7baf4868aaab2a2d11").appendChild(preEl);
#       });
#     }
#   }
#   // We may need to wait for loading to complete
#   function checkRender() {
#     if (typeof Viz === "undefined") { setTimeout(checkRender, 100+200*Math.random()); } else { doRender(); }
#   }
#   checkRender();
# })()
# </script>
# <div id="5e00c264771e46e4897b38bc00aa7742"></div>
# <script type="text/javascript" src="https://cdn.jsdelivr.net/npm/@viz-js/viz@3.8.0/lib/viz-standalone.js"></script>
# <script type="text/javascript">
# (function() {
#   var dot = "strict digraph {\nrankdir=LR;\ndpi=60;\nfontsize=16;\nranksep=0;\nnodesep=0.1;\nlabel=\"DSG Legend\";\nlabelloc=t;\nbgcolor=\"#f5f8fa\";\nnode [height=0];\nleg_0 [label=\"Source\", style=\"filled\", fillcolor=\"#ffffff\", shape=ellipse, margin=0];\nleg_1 [label=\"Selection\\nChoice\", style=\"filled\", fillcolor=\"#81D4FA\", shape=ellipse, margin=0];\nleg_2 [label=\"Option 1\", style=\"filled\", fillcolor=\"#ffffff\", shape=ellipse, margin=0];\nleg_3 [label=\"Option 2\", style=\"filled\", fillcolor=\"#ffffff\", shape=ellipse, margin=0];\nleg_4 [label=\"Etc...\", style=\"filled\", fillcolor=\"#ffffff\", shape=ellipse, margin=0];\nleg_5 [label=\"A\", style=\"filled\", fillcolor=\"#ffffff\", shape=ellipse, margin=0];\nleg_6 [label=\"B\", style=\"filled\", fillcolor=\"#ffffff\", shape=ellipse, margin=0];\nleg_7 [label=\"Node\", style=\"filled\", fillcolor=\"#ffffff\", shape=ellipse, margin=0];\nleg_8 [label=<<B>Start Node</B>>, style=\"filled,bold\", fillcolor=\"#ffffff\", shape=ellipse, margin=0];\nleg_0 -> leg_1 [type=\"EdgeType.DERIVES\"];\nleg_1 -> leg_2 [type=\"EdgeType.DERIVES\"];\nleg_1 -> leg_3 [type=\"EdgeType.DERIVES\"];\nleg_1 -> leg_4 [type=\"EdgeType.DERIVES\"];\nleg_5 -> leg_6 [label=derives, type=\"EdgeType.DERIVES\"];\n}\n"; // Export of the dot graph notation
#   var printDot = false; // Whether to print the dot instead of rendering
#   var printSvg = false; // Whether to print the SVG instead of showing the results
#   // Create viz-js instance and render to SVG
#   function doRender() {
#     if (printDot) {
#       var preEl = document.createElement('pre');
#       preEl.innerText = dot;
#       document.getElementById("5e00c264771e46e4897b38bc00aa7742").appendChild(preEl);
#     } else {
#       Viz.instance().then(function(viz) {
#         var tgtEl = document.getElementById("5e00c264771e46e4897b38bc00aa7742");
#         var svgElement = viz.renderSVGElement(dot);
#         if (printSvg) {
#           var preEl = document.createElement('pre');
#           preEl.innerText = svgElement.outerHTML;
#           tgtEl.appendChild(preEl);
#         } else {
#           tgtEl.appendChild(svgElement);
#         }
#       }).catch(function(e) {
#         console.log('RENDER ERROR', e, dot);
#         var preEl = document.createElement('pre');
#         preEl.innerText = 'RENDER ERROR: '+e.toString();
#         document.getElementById("5e00c264771e46e4897b38bc00aa7742").appendChild(preEl);
#         var preEl = document.createElement('pre');
#         preEl.innerText = dot;
#         document.getElementById("5e00c264771e46e4897b38bc00aa7742").appendChild(preEl);
#       });
#     }
#   }
#   // We may need to wait for loading to complete
#   function checkRender() {
#     if (typeof Viz === "undefined") { setTimeout(checkRender, 100+200*Math.random()); } else { doRender(); }
#   }
#   checkRender();
# })()
# </script>

# %% [markdown]
# Rendering all possible graphs shows that there are indeed 3 possible ways for selecting the 2 of 3 nodes in the set.

# %%
dsg.render_all()
# Out:
# Rendering 3 instances
# <div id="ee1339bee4c743229b98bbab47572985"></div>
# <script type="text/javascript" src="https://cdn.jsdelivr.net/npm/@viz-js/viz@3.8.0/lib/viz-standalone.js"></script>
# <script type="text/javascript">
# (function() {
#   var dot = "strict digraph {\nrankdir=LR;\ndpi=60;\nfontsize=20;\n0 [label=\"Opt 0\", style=\"filled\", fillcolor=\"#ffffff\", shape=ellipse, margin=0.05];\n1 [label=\"Node 0\", style=\"filled\", fillcolor=\"#ffffff\", shape=ellipse, margin=0.05];\n2 [label=\"Node 1\", style=\"filled\", fillcolor=\"#ffffff\", shape=ellipse, margin=0.05];\n3 [label=<<B>Selection</B>>, style=\"filled,bold\", fillcolor=\"#ffffff\", shape=ellipse, margin=0.05];\n0 -> 1 [type=\"EdgeType.DERIVES\"];\n0 -> 2 [type=\"EdgeType.DERIVES\"];\n3 -> 0 [type=\"EdgeType.DERIVES\"];\n}\n"; // Export of the dot graph notation
#   var printDot = false; // Whether to print the dot instead of rendering
#   var printSvg = false; // Whether to print the SVG instead of showing the results
#   // Create viz-js instance and render to SVG
#   function doRender() {
#     if (printDot) {
#       var preEl = document.createElement('pre');
#       preEl.innerText = dot;
#       document.getElementById("ee1339bee4c743229b98bbab47572985").appendChild(preEl);
#     } else {
#       Viz.instance().then(function(viz) {
#         var tgtEl = document.getElementById("ee1339bee4c743229b98bbab47572985");
#         var svgElement = viz.renderSVGElement(dot);
#         if (printSvg) {
#           var preEl = document.createElement('pre');
#           preEl.innerText = svgElement.outerHTML;
#           tgtEl.appendChild(preEl);
#         } else {
#           tgtEl.appendChild(svgElement);
#         }
#       }).catch(function(e) {
#         console.log('RENDER ERROR', e, dot);
#         var preEl = document.createElement('pre');
#         preEl.innerText = 'RENDER ERROR: '+e.toString();
#         document.getElementById("ee1339bee4c743229b98bbab47572985").appendChild(preEl);
#         var preEl = document.createElement('pre');
#         preEl.innerText = dot;
#         document.getElementById("ee1339bee4c743229b98bbab47572985").appendChild(preEl);
#       });
#     }
#   }
#   // We may need to wait for loading to complete
#   function checkRender() {
#     if (typeof Viz === "undefined") { setTimeout(checkRender, 100+200*Math.random()); } else { doRender(); }
#   }
#   checkRender();
# })()
# </script>
# <div id="e90678b92892401aa7601feaf640f7e4"></div>
#
# <script type="text/javascript">
# (function() {
#   var dot = "strict digraph {\nrankdir=LR;\ndpi=60;\nfontsize=20;\n0 [label=\"Opt 1\", style=\"filled\", fillcolor=\"#ffffff\", shape=ellipse, margin=0.05];\n1 [label=\"Node 0\", style=\"filled\", fillcolor=\"#ffffff\", shape=ellipse, margin=0.05];\n2 [label=\"Node 2\", style=\"filled\", fillcolor=\"#ffffff\", shape=ellipse, margin=0.05];\n3 [label=<<B>Selection</B>>, style=\"filled,bold\", fillcolor=\"#ffffff\", shape=ellipse, margin=0.05];\n0 -> 1 [type=\"EdgeType.DERIVES\"];\n0 -> 2 [type=\"EdgeType.DERIVES\"];\n3 -> 0 [type=\"EdgeType.DERIVES\"];\n}\n"; // Export of the dot graph notation
#   var printDot = false; // Whether to print the dot instead of rendering
#   var printSvg = false; // Whether to print the SVG instead of showing the results
#   // Create viz-js instance and render to SVG
#   function doRender() {
#     if (printDot) {
#       var preEl = document.createElement('pre');
#       preEl.innerText = dot;
#       document.getElementById("e90678b92892401aa7601feaf640f7e4").appendChild(preEl);
#     } else {
#       Viz.instance().then(function(viz) {
#         var tgtEl = document.getElementById("e90678b92892401aa7601feaf640f7e4");
#         var svgElement = viz.renderSVGElement(dot);
#         if (printSvg) {
#           var preEl = document.createElement('pre');
#           preEl.innerText = svgElement.outerHTML;
#           tgtEl.appendChild(preEl);
#         } else {
#           tgtEl.appendChild(svgElement);
#         }
#       }).catch(function(e) {
#         console.log('RENDER ERROR', e, dot);
#         var preEl = document.createElement('pre');
#         preEl.innerText = 'RENDER ERROR: '+e.toString();
#         document.getElementById("e90678b92892401aa7601feaf640f7e4").appendChild(preEl);
#         var preEl = document.createElement('pre');
#         preEl.innerText = dot;
#         document.getElementById("e90678b92892401aa7601feaf640f7e4").appendChild(preEl);
#       });
#     }
#   }
#   // We may need to wait for loading to complete
#   function checkRender() {
#     if (typeof Viz === "undefined") { setTimeout(checkRender, 100+200*Math.random()); } else { doRender(); }
#   }
#   checkRender();
# })()
# </script>
# <div id="23490f8ae1cf41169eb016668c017376"></div>
#
# <script type="text/javascript">
# (function() {
#   var dot = "strict digraph {\nrankdir=LR;\ndpi=60;\nfontsize=20;\n0 [label=\"Opt 2\", style=\"filled\", fillcolor=\"#ffffff\", shape=ellipse, margin=0.05];\n1 [label=\"Node 1\", style=\"filled\", fillcolor=\"#ffffff\", shape=ellipse, margin=0.05];\n2 [label=\"Node 2\", style=\"filled\", fillcolor=\"#ffffff\", shape=ellipse, margin=0.05];\n3 [label=<<B>Selection</B>>, style=\"filled,bold\", fillcolor=\"#ffffff\", shape=ellipse, margin=0.05];\n0 -> 1 [type=\"EdgeType.DERIVES\"];\n0 -> 2 [type=\"EdgeType.DERIVES\"];\n3 -> 0 [type=\"EdgeType.DERIVES\"];\n}\n"; // Export of the dot graph notation
#   var printDot = false; // Whether to print the dot instead of rendering
#   var printSvg = false; // Whether to print the SVG instead of showing the results
#   // Create viz-js instance and render to SVG
#   function doRender() {
#     if (printDot) {
#       var preEl = document.createElement('pre');
#       preEl.innerText = dot;
#       document.getElementById("23490f8ae1cf41169eb016668c017376").appendChild(preEl);
#     } else {
#       Viz.instance().then(function(viz) {
#         var tgtEl = document.getElementById("23490f8ae1cf41169eb016668c017376");
#         var svgElement = viz.renderSVGElement(dot);
#         if (printSvg) {
#           var preEl = document.createElement('pre');
#           preEl.innerText = svgElement.outerHTML;
#           tgtEl.appendChild(preEl);
#         } else {
#           tgtEl.appendChild(svgElement);
#         }
#       }).catch(function(e) {
#         console.log('RENDER ERROR', e, dot);
#         var preEl = document.createElement('pre');
#         preEl.innerText = 'RENDER ERROR: '+e.toString();
#         document.getElementById("23490f8ae1cf41169eb016668c017376").appendChild(preEl);
#         var preEl = document.createElement('pre');
#         preEl.innerText = dot;
#         document.getElementById("23490f8ae1cf41169eb016668c017376").appendChild(preEl);
#       });
#     }
#   }
#   // We may need to wait for loading to complete
#   function checkRender() {
#     if (typeof Viz === "undefined") { setTimeout(checkRender, 100+200*Math.random()); } else { doRender(); }
#   }
#   checkRender();
# })()
# </script>

# %% [markdown]
# In general, using intermediary nodes to define each option for selecting the actual option nodes is always a possibility if you want to use selection nodes.
#
# Another example is the choice of how many to select of an ordered set:

# %%
dsg = BasicDSG()

# Define the nodes of the ordered set
n = 5
nodes_in_set = [NamedNode(f'Node {i}') for i in range(n)]

# Define intermediary nodes for select n of this set
option_nodes = [nodes_in_set[0]]
for n_select in range(1, n):
    option_node = NamedNode(f'Opt {len(option_nodes)}')
    option_nodes.append(option_node)

    dsg.add_edges([(option_node, node_in_set) for node_in_set in nodes_in_set[:n_select+1]])

# Define the selection choice
start_node = NamedNode('Selection')
dsg.add_selection_choice(f'Select n of {n}', start_node, option_nodes)

dsg = dsg.set_start_nodes({start_node})

# Show the DSG (also works outside a notebook)
dsg.render()
# Out:
# <div id="d717537f55a2474c8935be0bf71d9d10"></div>
# <script type="text/javascript" src="https://cdn.jsdelivr.net/npm/@viz-js/viz@3.8.0/lib/viz-standalone.js"></script>
# <script type="text/javascript">
# (function() {
#   var dot = "strict digraph {\nrankdir=LR;\ndpi=60;\nfontsize=20;\n0 [label=\"Opt 1\", style=\"filled\", fillcolor=\"#ffffff\", shape=ellipse, margin=0.05];\n1 [label=\"Node 0\", style=\"filled\", fillcolor=\"#ffffff\", shape=ellipse, margin=0.05];\n2 [label=\"Node 1\", style=\"filled\", fillcolor=\"#ffffff\", shape=ellipse, margin=0.05];\n3 [label=\"Opt 2\", style=\"filled\", fillcolor=\"#ffffff\", shape=ellipse, margin=0.05];\n4 [label=\"Node 2\", style=\"filled\", fillcolor=\"#ffffff\", shape=ellipse, margin=0.05];\n5 [label=\"Opt 3\", style=\"filled\", fillcolor=\"#ffffff\", shape=ellipse, margin=0.05];\n6 [label=\"Node 3\", style=\"filled\", fillcolor=\"#ffffff\", shape=ellipse, margin=0.05];\n7 [label=\"Opt 4\", style=\"filled\", fillcolor=\"#ffffff\", shape=ellipse, margin=0.05];\n8 [label=\"Node 4\", style=\"filled\", fillcolor=\"#ffffff\", shape=ellipse, margin=0.05];\n9 [label=<<B>Selection</B>>, style=\"filled,bold\", fillcolor=\"#ffffff\", shape=ellipse, margin=0.05];\n10 [label=\"Select n of 5\", style=\"filled\", fillcolor=\"#81D4FA\", shape=ellipse, margin=0.05];\n0 -> 1 [type=\"EdgeType.DERIVES\"];\n0 -> 2 [type=\"EdgeType.DERIVES\"];\n3 -> 1 [type=\"EdgeType.DERIVES\"];\n3 -> 2 [type=\"EdgeType.DERIVES\"];\n3 -> 4 [type=\"EdgeType.DERIVES\"];\n5 -> 1 [type=\"EdgeType.DERIVES\"];\n5 -> 2 [type=\"EdgeType.DERIVES\"];\n5 -> 4 [type=\"EdgeType.DERIVES\"];\n5 -> 6 [type=\"EdgeType.DERIVES\"];\n7 -> 1 [type=\"EdgeType.DERIVES\"];\n7 -> 2 [type=\"EdgeType.DERIVES\"];\n7 -> 4 [type=\"EdgeType.DERIVES\"];\n7 -> 6 [type=\"EdgeType.DERIVES\"];\n7 -> 8 [type=\"EdgeType.DERIVES\"];\n9 -> 10 [type=\"EdgeType.DERIVES\"];\n10 -> 1 [type=\"EdgeType.DERIVES\"];\n10 -> 0 [type=\"EdgeType.DERIVES\"];\n10 -> 3 [type=\"EdgeType.DERIVES\"];\n10 -> 5 [type=\"EdgeType.DERIVES\"];\n10 -> 7 [type=\"EdgeType.DERIVES\"];\n}\n"; // Export of the dot graph notation
#   var printDot = false; // Whether to print the dot instead of rendering
#   var printSvg = false; // Whether to print the SVG instead of showing the results
#   // Create viz-js instance and render to SVG
#   function doRender() {
#     if (printDot) {
#       var preEl = document.createElement('pre');
#       preEl.innerText = dot;
#       document.getElementById("d717537f55a2474c8935be0bf71d9d10").appendChild(preEl);
#     } else {
#       Viz.instance().then(function(viz) {
#         var tgtEl = document.getElementById("d717537f55a2474c8935be0bf71d9d10");
#         var svgElement = viz.renderSVGElement(dot);
#         if (printSvg) {
#           var preEl = document.createElement('pre');
#           preEl.innerText = svgElement.outerHTML;
#           tgtEl.appendChild(preEl);
#         } else {
#           tgtEl.appendChild(svgElement);
#         }
#       }).catch(function(e) {
#         console.log('RENDER ERROR', e, dot);
#         var preEl = document.createElement('pre');
#         preEl.innerText = 'RENDER ERROR: '+e.toString();
#         document.getElementById("d717537f55a2474c8935be0bf71d9d10").appendChild(preEl);
#         var preEl = document.createElement('pre');
#         preEl.innerText = dot;
#         document.getElementById("d717537f55a2474c8935be0bf71d9d10").appendChild(preEl);
#       });
#     }
#   }
#   // We may need to wait for loading to complete
#   function checkRender() {
#     if (typeof Viz === "undefined") { setTimeout(checkRender, 100+200*Math.random()); } else { doRender(); }
#   }
#   checkRender();
# })()
# </script>

# %% [markdown]
# ### Using `itertools` to Define Options
#
# Scenarios such as "select k of n" with a fixed or variable `k` can be implemented using `itertools` to iterate over all possible combinations.
#
# The same "2 of 3" example as before, now using `itertools`:

# %%
import itertools
from adsg_core import BasicDSG, NamedNode

def get_dsg_k_of_n(k, n):
    # Create the DSG
    dsg = BasicDSG()
    
    # Define the nodes in the set to be selected
    nodes_in_set = [NamedNode(f'Node {i}') for i in range(n)]
    
    # Define the distinct options of the selection node, one for each combination of selecting 2 of 3:
    # Select nodes 1 and 2, select nodes 1 and 3, or select nodes 2 and 3.
    option_nodes = []
    for selected_nodes_in_set in itertools.combinations(nodes_in_set, k):
        option_node = NamedNode(f'Opt {len(option_nodes)}')
        option_nodes.append(option_node)
        dsg.add_edges([(option_node, node_in_set) for node_in_set in selected_nodes_in_set])

    print(f'There are {len(option_nodes)} ways to select {k} of {n}.')
    
    # Define the selection choice
    start_node = NamedNode('Selection')
    dsg.add_selection_choice(f'Select {k} of {n}', start_node, option_nodes)
    
    return dsg.set_start_nodes({start_node})

# Create DSG for "2 of 3"
dsg = get_dsg_k_of_n(k=2, n=3)

# Show the DSG (also works outside a notebook)
dsg.render()
# Out:
# There are 3 ways to select 2 of 3.
# <div id="2c1b971d2b044a079fea84a25b2843d7"></div>
# <script type="text/javascript" src="https://cdn.jsdelivr.net/npm/@viz-js/viz@3.8.0/lib/viz-standalone.js"></script>
# <script type="text/javascript">
# (function() {
#   var dot = "strict digraph {\nrankdir=LR;\ndpi=60;\nfontsize=20;\n0 [label=\"Opt 0\", style=\"filled\", fillcolor=\"#ffffff\", shape=ellipse, margin=0.05];\n1 [label=\"Node 0\", style=\"filled\", fillcolor=\"#ffffff\", shape=ellipse, margin=0.05];\n2 [label=\"Node 1\", style=\"filled\", fillcolor=\"#ffffff\", shape=ellipse, margin=0.05];\n3 [label=\"Opt 1\", style=\"filled\", fillcolor=\"#ffffff\", shape=ellipse, margin=0.05];\n4 [label=\"Node 2\", style=\"filled\", fillcolor=\"#ffffff\", shape=ellipse, margin=0.05];\n5 [label=\"Opt 2\", style=\"filled\", fillcolor=\"#ffffff\", shape=ellipse, margin=0.05];\n6 [label=<<B>Selection</B>>, style=\"filled,bold\", fillcolor=\"#ffffff\", shape=ellipse, margin=0.05];\n7 [label=\"Select 2 of 3\", style=\"filled\", fillcolor=\"#81D4FA\", shape=ellipse, margin=0.05];\n0 -> 1 [type=\"EdgeType.DERIVES\"];\n0 -> 2 [type=\"EdgeType.DERIVES\"];\n3 -> 1 [type=\"EdgeType.DERIVES\"];\n3 -> 4 [type=\"EdgeType.DERIVES\"];\n5 -> 2 [type=\"EdgeType.DERIVES\"];\n5 -> 4 [type=\"EdgeType.DERIVES\"];\n6 -> 7 [type=\"EdgeType.DERIVES\"];\n7 -> 0 [type=\"EdgeType.DERIVES\"];\n7 -> 3 [type=\"EdgeType.DERIVES\"];\n7 -> 5 [type=\"EdgeType.DERIVES\"];\n}\n"; // Export of the dot graph notation
#   var printDot = false; // Whether to print the dot instead of rendering
#   var printSvg = false; // Whether to print the SVG instead of showing the results
#   // Create viz-js instance and render to SVG
#   function doRender() {
#     if (printDot) {
#       var preEl = document.createElement('pre');
#       preEl.innerText = dot;
#       document.getElementById("2c1b971d2b044a079fea84a25b2843d7").appendChild(preEl);
#     } else {
#       Viz.instance().then(function(viz) {
#         var tgtEl = document.getElementById("2c1b971d2b044a079fea84a25b2843d7");
#         var svgElement = viz.renderSVGElement(dot);
#         if (printSvg) {
#           var preEl = document.createElement('pre');
#           preEl.innerText = svgElement.outerHTML;
#           tgtEl.appendChild(preEl);
#         } else {
#           tgtEl.appendChild(svgElement);
#         }
#       }).catch(function(e) {
#         console.log('RENDER ERROR', e, dot);
#         var preEl = document.createElement('pre');
#         preEl.innerText = 'RENDER ERROR: '+e.toString();
#         document.getElementById("2c1b971d2b044a079fea84a25b2843d7").appendChild(preEl);
#         var preEl = document.createElement('pre');
#         preEl.innerText = dot;
#         document.getElementById("2c1b971d2b044a079fea84a25b2843d7").appendChild(preEl);
#       });
#     }
#   }
#   // We may need to wait for loading to complete
#   function checkRender() {
#     if (typeof Viz === "undefined") { setTimeout(checkRender, 100+200*Math.random()); } else { doRender(); }
#   }
#   checkRender();
# })()
# </script>

# %% [markdown]
# The number of intermediate option nodes grows quickly with k or n

# %%
get_dsg_k_of_n(k=2, n=4).render()
get_dsg_k_of_n(k=3, n=6).render()
get_dsg_k_of_n(k=4, n=8);
# Out:
# There are 6 ways to select 2 of 4.
# <div id="7cab23ccc43445afb93fba8960a811e4"></div>
# <script type="text/javascript" src="https://cdn.jsdelivr.net/npm/@viz-js/viz@3.8.0/lib/viz-standalone.js"></script>
# <script type="text/javascript">
# (function() {
#   var dot = "strict digraph {\nrankdir=LR;\ndpi=60;\nfontsize=20;\n0 [label=\"Opt 0\", style=\"filled\", fillcolor=\"#ffffff\", shape=ellipse, margin=0.05];\n1 [label=\"Node 0\", style=\"filled\", fillcolor=\"#ffffff\", shape=ellipse, margin=0.05];\n2 [label=\"Node 1\", style=\"filled\", fillcolor=\"#ffffff\", shape=ellipse, margin=0.05];\n3 [label=\"Opt 1\", style=\"filled\", fillcolor=\"#ffffff\", shape=ellipse, margin=0.05];\n4 [label=\"Node 2\", style=\"filled\", fillcolor=\"#ffffff\", shape=ellipse, margin=0.05];\n5 [label=\"Opt 2\", style=\"filled\", fillcolor=\"#ffffff\", shape=ellipse, margin=0.05];\n6 [label=\"Node 3\", style=\"filled\", fillcolor=\"#ffffff\", shape=ellipse, margin=0.05];\n7 [label=\"Opt 3\", style=\"filled\", fillcolor=\"#ffffff\", shape=ellipse, margin=0.05];\n8 [label=\"Opt 4\", style=\"filled\", fillcolor=\"#ffffff\", shape=ellipse, margin=0.05];\n9 [label=\"Opt 5\", style=\"filled\", fillcolor=\"#ffffff\", shape=ellipse, margin=0.05];\n10 [label=<<B>Selection</B>>, style=\"filled,bold\", fillcolor=\"#ffffff\", shape=ellipse, margin=0.05];\n11 [label=\"Select 2 of 4\", style=\"filled\", fillcolor=\"#81D4FA\", shape=ellipse, margin=0.05];\n0 -> 1 [type=\"EdgeType.DERIVES\"];\n0 -> 2 [type=\"EdgeType.DERIVES\"];\n3 -> 1 [type=\"EdgeType.DERIVES\"];\n3 -> 4 [type=\"EdgeType.DERIVES\"];\n5 -> 1 [type=\"EdgeType.DERIVES\"];\n5 -> 6 [type=\"EdgeType.DERIVES\"];\n7 -> 2 [type=\"EdgeType.DERIVES\"];\n7 -> 4 [type=\"EdgeType.DERIVES\"];\n8 -> 2 [type=\"EdgeType.DERIVES\"];\n8 -> 6 [type=\"EdgeType.DERIVES\"];\n9 -> 4 [type=\"EdgeType.DERIVES\"];\n9 -> 6 [type=\"EdgeType.DERIVES\"];\n10 -> 11 [type=\"EdgeType.DERIVES\"];\n11 -> 0 [type=\"EdgeType.DERIVES\"];\n11 -> 3 [type=\"EdgeType.DERIVES\"];\n11 -> 5 [type=\"EdgeType.DERIVES\"];\n11 -> 7 [type=\"EdgeType.DERIVES\"];\n11 -> 8 [type=\"EdgeType.DERIVES\"];\n11 -> 9 [type=\"EdgeType.DERIVES\"];\n}\n"; // Export of the dot graph notation
#   var printDot = false; // Whether to print the dot instead of rendering
#   var printSvg = false; // Whether to print the SVG instead of showing the results
#   // Create viz-js instance and render to SVG
#   function doRender() {
#     if (printDot) {
#       var preEl = document.createElement('pre');
#       preEl.innerText = dot;
#       document.getElementById("7cab23ccc43445afb93fba8960a811e4").appendChild(preEl);
#     } else {
#       Viz.instance().then(function(viz) {
#         var tgtEl = document.getElementById("7cab23ccc43445afb93fba8960a811e4");
#         var svgElement = viz.renderSVGElement(dot);
#         if (printSvg) {
#           var preEl = document.createElement('pre');
#           preEl.innerText = svgElement.outerHTML;
#           tgtEl.appendChild(preEl);
#         } else {
#           tgtEl.appendChild(svgElement);
#         }
#       }).catch(function(e) {
#         console.log('RENDER ERROR', e, dot);
#         var preEl = document.createElement('pre');
#         preEl.innerText = 'RENDER ERROR: '+e.toString();
#         document.getElementById("7cab23ccc43445afb93fba8960a811e4").appendChild(preEl);
#         var preEl = document.createElement('pre');
#         preEl.innerText = dot;
#         document.getElementById("7cab23ccc43445afb93fba8960a811e4").appendChild(preEl);
#       });
#     }
#   }
#   // We may need to wait for loading to complete
#   function checkRender() {
#     if (typeof Viz === "undefined") { setTimeout(checkRender, 100+200*Math.random()); } else { doRender(); }
#   }
#   checkRender();
# })()
# </script>
# There are 20 ways to select 3 of 6.
# <div id="dab216c68e614617b541ed5236d1fcd2"></div>
# <script type="text/javascript" src="https://cdn.jsdelivr.net/npm/@viz-js/viz@3.8.0/lib/viz-standalone.js"></script>
# <script type="text/javascript">
# (function() {
#   var dot = "strict digraph {\nrankdir=LR;\ndpi=60;\nfontsize=20;\n0 [label=\"Opt 0\", style=\"filled\", fillcolor=\"#ffffff\", shape=ellipse, margin=0.05];\n1 [label=\"Node 0\", style=\"filled\", fillcolor=\"#ffffff\", shape=ellipse, margin=0.05];\n2 [label=\"Node 1\", style=\"filled\", fillcolor=\"#ffffff\", shape=ellipse, margin=0.05];\n3 [label=\"Node 2\", style=\"filled\", fillcolor=\"#ffffff\", shape=ellipse, margin=0.05];\n4 [label=\"Opt 1\", style=\"filled\", fillcolor=\"#ffffff\", shape=ellipse, margin=0.05];\n5 [label=\"Node 3\", style=\"filled\", fillcolor=\"#ffffff\", shape=ellipse, margin=0.05];\n6 [label=\"Opt 2\", style=\"filled\", fillcolor=\"#ffffff\", shape=ellipse, margin=0.05];\n7 [label=\"Node 4\", style=\"filled\", fillcolor=\"#ffffff\", shape=ellipse, margin=0.05];\n8 [label=\"Opt 3\", style=\"filled\", fillcolor=\"#ffffff\", shape=ellipse, margin=0.05];\n9 [label=\"Node 5\", style=\"filled\", fillcolor=\"#ffffff\", shape=ellipse, margin=0.05];\n10 [label=\"Opt 4\", style=\"filled\", fillcolor=\"#ffffff\", shape=ellipse, margin=0.05];\n11 [label=\"Opt 5\", style=\"filled\", fillcolor=\"#ffffff\", shape=ellipse, margin=0.05];\n12 [label=\"Opt 6\", style=\"filled\", fillcolor=\"#ffffff\", shape=ellipse, margin=0.05];\n13 [label=\"Opt 7\", style=\"filled\", fillcolor=\"#ffffff\", shape=ellipse, margin=0.05];\n14 [label=\"Opt 8\", style=\"filled\", fillcolor=\"#ffffff\", shape=ellipse, margin=0.05];\n15 [label=\"Opt 9\", style=\"filled\", fillcolor=\"#ffffff\", shape=ellipse, margin=0.05];\n16 [label=\"Opt 10\", style=\"filled\", fillcolor=\"#ffffff\", shape=ellipse, margin=0.05];\n17 [label=\"Opt 11\", style=\"filled\", fillcolor=\"#ffffff\", shape=ellipse, margin=0.05];\n18 [label=\"Opt 12\", style=\"filled\", fillcolor=\"#ffffff\", shape=ellipse, margin=0.05];\n19 [label=\"Opt 13\", style=\"filled\", fillcolor=\"#ffffff\", shape=ellipse, margin=0.05];\n20 [label=\"Opt 14\", style=\"filled\", fillcolor=\"#ffffff\", shape=ellipse, margin=0.05];\n21 [label=\"Opt 15\", style=\"filled\", fillcolor=\"#ffffff\", shape=ellipse, margin=0.05];\n22 [label=\"Opt 16\", style=\"filled\", fillcolor=\"#ffffff\", shape=ellipse, margin=0.05];\n23 [label=\"Opt 17\", style=\"filled\", fillcolor=\"#ffffff\", shape=ellipse, margin=0.05];\n24 [label=\"Opt 18\", style=\"filled\", fillcolor=\"#ffffff\", shape=ellipse, margin=0.05];\n25 [label=\"Opt 19\", style=\"filled\", fillcolor=\"#ffffff\", shape=ellipse, margin=0.05];\n26 [label=<<B>Selection</B>>, style=\"filled,bold\", fillcolor=\"#ffffff\", shape=ellipse, margin=0.05];\n27 [label=\"Select 3 of 6\", style=\"filled\", fillcolor=\"#81D4FA\", shape=ellipse, margin=0.05];\n0 -> 1 [type=\"EdgeType.DERIVES\"];\n0 -> 2 [type=\"EdgeType.DERIVES\"];\n0 -> 3 [type=\"EdgeType.DERIVES\"];\n4 -> 1 [type=\"EdgeType.DERIVES\"];\n4 -> 2 [type=\"EdgeType.DERIVES\"];\n4 -> 5 [type=\"EdgeType.DERIVES\"];\n6 -> 1 [type=\"EdgeType.DERIVES\"];\n6 -> 2 [type=\"EdgeType.DERIVES\"];\n6 -> 7 [type=\"EdgeType.DERIVES\"];\n8 -> 1 [type=\"EdgeType.DERIVES\"];\n8 -> 2 [type=\"EdgeType.DERIVES\"];\n8 -> 9 [type=\"EdgeType.DERIVES\"];\n10 -> 1 [type=\"EdgeType.DERIVES\"];\n10 -> 3 [type=\"EdgeType.DERIVES\"];\n10 -> 5 [type=\"EdgeType.DERIVES\"];\n11 -> 1 [type=\"EdgeType.DERIVES\"];\n11 -> 3 [type=\"EdgeType.DERIVES\"];\n11 -> 7 [type=\"EdgeType.DERIVES\"];\n12 -> 1 [type=\"EdgeType.DERIVES\"];\n12 -> 3 [type=\"EdgeType.DERIVES\"];\n12 -> 9 [type=\"EdgeType.DERIVES\"];\n13 -> 1 [type=\"EdgeType.DERIVES\"];\n13 -> 5 [type=\"EdgeType.DERIVES\"];\n13 -> 7 [type=\"EdgeType.DERIVES\"];\n14 -> 1 [type=\"EdgeType.DERIVES\"];\n14 -> 5 [type=\"EdgeType.DERIVES\"];\n14 -> 9 [type=\"EdgeType.DERIVES\"];\n15 -> 1 [type=\"EdgeType.DERIVES\"];\n15 -> 7 [type=\"EdgeType.DERIVES\"];\n15 -> 9 [type=\"EdgeType.DERIVES\"];\n16 -> 2 [type=\"EdgeType.DERIVES\"];\n16 -> 3 [type=\"EdgeType.DERIVES\"];\n16 -> 5 [type=\"EdgeType.DERIVES\"];\n17 -> 2 [type=\"EdgeType.DERIVES\"];\n17 -> 3 [type=\"EdgeType.DERIVES\"];\n17 -> 7 [ty ...
#   var printDot = false; // Whether to print the dot instead of rendering
#   var printSvg = false; // Whether to print the SVG instead of showing the results
#   // Create viz-js instance and render to SVG
#   function doRender() {
#     if (printDot) {
#       var preEl = document.createElement('pre');
#       preEl.innerText = dot;
#       document.getElementById("dab216c68e614617b541ed5236d1fcd2").appendChild(preEl);
#     } else {
#       Viz.instance().then(function(viz) {
#         var tgtEl = document.getElementById("dab216c68e614617b541ed5236d1fcd2");
#         var svgElement = viz.renderSVGElement(dot);
#         if (printSvg) {
#           var preEl = document.createElement('pre');
#           preEl.innerText = svgElement.outerHTML;
#           tgtEl.appendChild(preEl);
#         } else {
#           tgtEl.appendChild(svgElement);
#         }
#       }).catch(function(e) {
#         console.log('RENDER ERROR', e, dot);
#         var preEl = document.createElement('pre');
#         preEl.innerText = 'RENDER ERROR: '+e.toString();
#         document.getElementById("dab216c68e614617b541ed5236d1fcd2").appendChild(preEl);
#         var preEl = document.createElement('pre');
#         preEl.innerText = dot;
#         document.getElementById("dab216c68e614617b541ed5236d1fcd2").appendChild(preEl);
#       });
#     }
#   }
#   // We may need to wait for loading to complete
#   function checkRender() {
#     if (typeof Viz === "undefined") { setTimeout(checkRender, 100+200*Math.random()); } else { doRender(); }
#   }
#   checkRender();
# })()
# </script>
# There are 70 ways to select 4 of 8.

# %% [markdown]
# ## Using Connection Choices for Advanced Selection Cardinality
#
# Connection choices are designed to make it easy to define advanced cardinality choices out of the box, however do not influence node selection by themselves. Two helper functionalities are provided to make available the power of connection choices for node selection too:
# 1. Deriving target nodes from source nodes, so that target nodes do not have to be derived from other sources.
# 2. Removing unconnected source and/or target nodes from the graph, so that connection choices can also be used for node selection.
#
# To demonstrate this, consider the "k of n" combinations scenario of before:

# %%
from adsg_core import BasicDSG, ConnectorNode, GraphProcessor

def get_dsg_k_of_n_using_conn_choice(k, n):
    # Create the DSG
    dsg = BasicDSG()

    # Define the source connector node to have k connections
    source_node = ConnectorNode(f'Select {k}', deg_list=[k])
    
    # Define the nodes in the set to be selected:
    # Each can either be connected to or not, and will be removed if unconnected
    target_nodes = [ConnectorNode(f'Node {i}', deg_list=[0, 1], remove_if_unconnected=True) for i in range(n)]
    
    # Define the connection choice
    # We set `derive_tgt_nodes=True` to make sure that the target nodes are indeed derived from the source node
    dsg.add_connection_choice(f'Select {k} of {n}', [source_node], target_nodes, derive_tgt_nodes=True)
    
    # Count the number of possible graphs
    dsg = dsg.set_start_nodes({source_node})

    processor = GraphProcessor(dsg)
    n_graphs = processor.get_n_valid_designs()
    print(f'There are {n_graphs} ways to select {k} of {n}.')

    return dsg

# Create DSG for "2 of 3"
dsg = get_dsg_k_of_n_using_conn_choice(k=2, n=3)

# Some additional nodes are automatically added:
# - A "collector" node that collects derivation edges from source nodes and derives all target nodes
# - Selection choice nodes for selecting whether each of the target node exists
# - A non-selection node used as the option for not selecting a target node

dsg.render()
dsg.render_legend(['NODE_CONNECTOR', 'EDGE_DERIVE', 'EDGE_CONNECT', 'CHOICE_SEL', 'CHOICE_CONN'])
# Out:
# There are 3 ways to select 2 of 3.
# <div id="8ac0cc953efc40f2a51dccc0771fe955"></div>
# <script type="text/javascript" src="https://cdn.jsdelivr.net/npm/@viz-js/viz@3.8.0/lib/viz-standalone.js"></script>
# <script type="text/javascript">
# (function() {
#   var dot = "strict digraph {\nrankdir=LR;\ndpi=60;\nfontsize=20;\n0 [label=<<B>Select 2</B>>, style=\"filled,bold\", fillcolor=\"#ffffff\", shape=hexagon, margin=0.05];\n1 [label=\"Select 2 of 3\", style=\"filled\", fillcolor=\"#81D4FA\", shape=hexagon, margin=0.05];\n2 [label=\"Col\", style=\"filled\", fillcolor=\"#ffffff\", shape=ellipse, margin=0.05];\n3 [label=\"Node 0\", style=\"filled\", fillcolor=\"#ffffff\", shape=hexagon, margin=0.05];\n4 [label=\"Node 1\", style=\"filled\", fillcolor=\"#ffffff\", shape=hexagon, margin=0.05];\n5 [label=\"Node 2\", style=\"filled\", fillcolor=\"#ffffff\", shape=hexagon, margin=0.05];\n6 [label=\"CONN_Select 2 of 3_SEL_Node 0\", style=\"filled\", fillcolor=\"#81D4FA\", shape=ellipse, margin=0.05];\n7 [label=\"CONN_Select 2 of 3_SEL_Node 1\", style=\"filled\", fillcolor=\"#81D4FA\", shape=ellipse, margin=0.05];\n8 [label=\"CONN_Select 2 of 3_SEL_Node 2\", style=\"filled\", fillcolor=\"#81D4FA\", shape=ellipse, margin=0.05];\n9 [label=\"NonSel\", style=\"filled\", fillcolor=\"#ffffff\", shape=ellipse, margin=0.05];\n0 -> 1 [type=\"EdgeType.CONNECTS\", style=dashed, label=\"2\"];\n0 -> 2 [type=\"EdgeType.DERIVES\"];\n1 -> 3 [type=\"EdgeType.CONNECTS\", style=dashed, label=\"1\"];\n1 -> 4 [type=\"EdgeType.CONNECTS\", style=dashed, label=\"1\"];\n1 -> 5 [type=\"EdgeType.CONNECTS\", style=dashed, label=\"1\"];\n2 -> 6 [type=\"EdgeType.DERIVES\"];\n2 -> 7 [type=\"EdgeType.DERIVES\"];\n2 -> 8 [type=\"EdgeType.DERIVES\"];\n6 -> 9 [type=\"EdgeType.DERIVES\"];\n6 -> 3 [type=\"EdgeType.DERIVES\"];\n7 -> 9 [type=\"EdgeType.DERIVES\"];\n7 -> 4 [type=\"EdgeType.DERIVES\"];\n8 -> 9 [type=\"EdgeType.DERIVES\"];\n8 -> 5 [type=\"EdgeType.DERIVES\"];\n}\n"; // Export of the dot graph notation
#   var printDot = false; // Whether to print the dot instead of rendering
#   var printSvg = false; // Whether to print the SVG instead of showing the results
#   // Create viz-js instance and render to SVG
#   function doRender() {
#     if (printDot) {
#       var preEl = document.createElement('pre');
#       preEl.innerText = dot;
#       document.getElementById("8ac0cc953efc40f2a51dccc0771fe955").appendChild(preEl);
#     } else {
#       Viz.instance().then(function(viz) {
#         var tgtEl = document.getElementById("8ac0cc953efc40f2a51dccc0771fe955");
#         var svgElement = viz.renderSVGElement(dot);
#         if (printSvg) {
#           var preEl = document.createElement('pre');
#           preEl.innerText = svgElement.outerHTML;
#           tgtEl.appendChild(preEl);
#         } else {
#           tgtEl.appendChild(svgElement);
#         }
#       }).catch(function(e) {
#         console.log('RENDER ERROR', e, dot);
#         var preEl = document.createElement('pre');
#         preEl.innerText = 'RENDER ERROR: '+e.toString();
#         document.getElementById("8ac0cc953efc40f2a51dccc0771fe955").appendChild(preEl);
#         var preEl = document.createElement('pre');
#         preEl.innerText = dot;
#         document.getElementById("8ac0cc953efc40f2a51dccc0771fe955").appendChild(preEl);
#       });
#     }
#   }
#   // We may need to wait for loading to complete
#   function checkRender() {
#     if (typeof Viz === "undefined") { setTimeout(checkRender, 100+200*Math.random()); } else { doRender(); }
#   }
#   checkRender();
# })()
# </script>
# <div id="11dad02eb3ef48f19dd6a3b2eecfd7c2"></div>
# <script type="text/javascript" src="https://cdn.jsdelivr.net/npm/@viz-js/viz@3.8.0/lib/viz-standalone.js"></script>
# <script type="text/javascript">
# (function() {
#   var dot = "strict digraph {\nrankdir=LR;\ndpi=60;\nfontsize=16;\nranksep=0;\nnodesep=0.1;\nlabel=\"DSG Legend\";\nlabelloc=t;\nbgcolor=\"#f5f8fa\";\nnode [height=0];\nleg_0 [label=\"Source 1\", style=\"filled\", fillcolor=\"#ffffff\", shape=hexagon, margin=0];\nleg_1 [label=\"Connection\\nChoice\", style=\"filled\", fillcolor=\"#81D4FA\", shape=hexagon, margin=0];\nleg_2 [label=\"Target 1\", style=\"filled\", fillcolor=\"#ffffff\", shape=hexagon, margin=0];\nleg_3 [label=\"Target 2\", style=\"filled\", fillcolor=\"#ffffff\", shape=hexagon, margin=0];\nleg_4 [label=\"Source 2\", style=\"filled\", fillcolor=\"#ffffff\", shape=hexagon, margin=0];\nleg_5 [label=\"Source 2\", style=\"filled\", fillcolor=\"#ffffff\", shape=hexagon, margin=0];\nleg_6 [label=\"Source\", style=\"filled\", fillcolor=\"#ffffff\", shape=ellipse, margin=0];\nleg_7 [label=\"Selection\\nChoice\", style=\"filled\", fillcolor=\"#81D4FA\", shape=ellipse, margin=0];\nleg_8 [label=\"Option 1\", style=\"filled\", fillcolor=\"#ffffff\", shape=ellipse, margin=0];\nleg_9 [label=\"Option 2\", style=\"filled\", fillcolor=\"#ffffff\", shape=ellipse, margin=0];\nleg_10 [label=\"Etc...\", style=\"filled\", fillcolor=\"#ffffff\", shape=ellipse, margin=0];\nleg_11 [label=\"C\", style=\"filled\", fillcolor=\"#ffffff\", shape=ellipse, margin=0];\nleg_12 [label=\"D\", style=\"filled\", fillcolor=\"#ffffff\", shape=ellipse, margin=0];\nleg_13 [label=\"A\", style=\"filled\", fillcolor=\"#ffffff\", shape=ellipse, margin=0];\nleg_14 [label=\"B\", style=\"filled\", fillcolor=\"#ffffff\", shape=ellipse, margin=0];\nleg_15 [label=\"Connector\", style=\"filled\", fillcolor=\"#ffffff\", shape=hexagon, margin=0];\nleg_0 -> leg_1 [type=\"EdgeType.CONNECTS\", style=dashed, label=\"1\"];\nleg_1 -> leg_2 [type=\"EdgeType.CONNECTS\", style=dashed, label=\"1..* \u2225\"];\nleg_1 -> leg_3 [type=\"EdgeType.CONNECTS\", style=dashed, label=\"0..2\"];\nleg_4 -> leg_1 [type=\"EdgeType.CONNECTS\", style=dashed, label=\"0,1\"];\nleg_5 -> leg_1 [type=\"EdgeType.CONNECTS\", style=dashed, label=\"0..* \u2225\"];\nleg_6 -> leg_7 [type=\"EdgeType.DERIVES\"];\nleg_7 -> leg_8 [type=\"EdgeType.DERIVES\"];\nleg_7 -> leg_9 [type=\"EdgeType.DERIVES\"];\nleg_7 -> leg_10 [type=\"EdgeType.DERIVES\"];\nleg_11 -> leg_12 [label=\"connects to\", type=\"EdgeType.CONNECTS\", style=dashed];\nleg_13 -> leg_14 [label=derives, type=\"EdgeType.DERIVES\"];\n}\n"; // Export of the dot graph notation
#   var printDot = false; // Whether to print the dot instead of rendering
#   var printSvg = false; // Whether to print the SVG instead of showing the results
#   // Create viz-js instance and render to SVG
#   function doRender() {
#     if (printDot) {
#       var preEl = document.createElement('pre');
#       preEl.innerText = dot;
#       document.getElementById("11dad02eb3ef48f19dd6a3b2eecfd7c2").appendChild(preEl);
#     } else {
#       Viz.instance().then(function(viz) {
#         var tgtEl = document.getElementById("11dad02eb3ef48f19dd6a3b2eecfd7c2");
#         var svgElement = viz.renderSVGElement(dot);
#         if (printSvg) {
#           var preEl = document.createElement('pre');
#           preEl.innerText = svgElement.outerHTML;
#           tgtEl.appendChild(preEl);
#         } else {
#           tgtEl.appendChild(svgElement);
#         }
#       }).catch(function(e) {
#         console.log('RENDER ERROR', e, dot);
#         var preEl = document.createElement('pre');
#         preEl.innerText = 'RENDER ERROR: '+e.toString();
#         document.getElementById("11dad02eb3ef48f19dd6a3b2eecfd7c2").appendChild(preEl);
#         var preEl = document.createElement('pre');
#         preEl.innerText = dot;
#         document.getElementById("11dad02eb3ef48f19dd6a3b2eecfd7c2").appendChild(preEl);
#       });
#     }
#   }
#   // We may need to wait for loading to complete
#   function checkRender() {
#     if (typeof Viz === "undefined") { setTimeout(checkRender, 100+200*Math.random()); } else { doRender(); }
#   }
#   checkRender();
# })()
# </script>

# %%
# Again, there are 3 ways to select the target nodes
dsg.render_all([0])
# Out:
# Rendering 1 of 3 instances
# <div id="76a85f0b02e647cba23732d124c42f88"></div>
# <script type="text/javascript" src="https://cdn.jsdelivr.net/npm/@viz-js/viz@3.8.0/lib/viz-standalone.js"></script>
# <script type="text/javascript">
# (function() {
#   var dot = "strict digraph {\nrankdir=LR;\ndpi=60;\nfontsize=20;\n0 [label=<<B>Select 2</B>>, style=\"filled,bold\", fillcolor=\"#ffffff\", shape=hexagon, margin=0.05];\n1 [label=\"Col\", style=\"filled\", fillcolor=\"#ffffff\", shape=ellipse, margin=0.05];\n2 [label=\"Node 2\", style=\"filled\", fillcolor=\"#ffffff\", shape=hexagon, margin=0.05];\n3 [label=\"Node 1\", style=\"filled\", fillcolor=\"#ffffff\", shape=hexagon, margin=0.05];\n4 [label=\"NonSel\", style=\"filled\", fillcolor=\"#ffffff\", shape=ellipse, margin=0.05];\n0 -> 1 [type=\"EdgeType.DERIVES\"];\n0 -> 2 [type=\"EdgeType.CONNECTS\", style=dashed];\n0 -> 3 [type=\"EdgeType.CONNECTS\", style=dashed];\n1 -> 4 [type=\"EdgeType.DERIVES\"];\n1 -> 3 [type=\"EdgeType.DERIVES\"];\n1 -> 2 [type=\"EdgeType.DERIVES\"];\n}\n"; // Export of the dot graph notation
#   var printDot = false; // Whether to print the dot instead of rendering
#   var printSvg = false; // Whether to print the SVG instead of showing the results
#   // Create viz-js instance and render to SVG
#   function doRender() {
#     if (printDot) {
#       var preEl = document.createElement('pre');
#       preEl.innerText = dot;
#       document.getElementById("76a85f0b02e647cba23732d124c42f88").appendChild(preEl);
#     } else {
#       Viz.instance().then(function(viz) {
#         var tgtEl = document.getElementById("76a85f0b02e647cba23732d124c42f88");
#         var svgElement = viz.renderSVGElement(dot);
#         if (printSvg) {
#           var preEl = document.createElement('pre');
#           preEl.innerText = svgElement.outerHTML;
#           tgtEl.appendChild(preEl);
#         } else {
#           tgtEl.appendChild(svgElement);
#         }
#       }).catch(function(e) {
#         console.log('RENDER ERROR', e, dot);
#         var preEl = document.createElement('pre');
#         preEl.innerText = 'RENDER ERROR: '+e.toString();
#         document.getElementById("76a85f0b02e647cba23732d124c42f88").appendChild(preEl);
#         var preEl = document.createElement('pre');
#         preEl.innerText = dot;
#         document.getElementById("76a85f0b02e647cba23732d124c42f88").appendChild(preEl);
#       });
#     }
#   }
#   // We may need to wait for loading to complete
#   function checkRender() {
#     if (typeof Viz === "undefined") { setTimeout(checkRender, 100+200*Math.random()); } else { doRender(); }
#   }
#   checkRender();
# })()
# </script>

# %%
get_dsg_k_of_n_using_conn_choice(k=2, n=4).render()
get_dsg_k_of_n_using_conn_choice(k=3, n=6).render()
get_dsg_k_of_n_using_conn_choice(k=4, n=8);
# Out:
# There are 6 ways to select 2 of 4.
# <div id="f6bcef1d11c64203bfd6dd5d61422756"></div>
# <script type="text/javascript" src="https://cdn.jsdelivr.net/npm/@viz-js/viz@3.8.0/lib/viz-standalone.js"></script>
# <script type="text/javascript">
# (function() {
#   var dot = "strict digraph {\nrankdir=LR;\ndpi=60;\nfontsize=20;\n0 [label=<<B>Select 2</B>>, style=\"filled,bold\", fillcolor=\"#ffffff\", shape=hexagon, margin=0.05];\n1 [label=\"Select 2 of 4\", style=\"filled\", fillcolor=\"#81D4FA\", shape=hexagon, margin=0.05];\n2 [label=\"Col\", style=\"filled\", fillcolor=\"#ffffff\", shape=ellipse, margin=0.05];\n3 [label=\"Node 0\", style=\"filled\", fillcolor=\"#ffffff\", shape=hexagon, margin=0.05];\n4 [label=\"Node 1\", style=\"filled\", fillcolor=\"#ffffff\", shape=hexagon, margin=0.05];\n5 [label=\"Node 2\", style=\"filled\", fillcolor=\"#ffffff\", shape=hexagon, margin=0.05];\n6 [label=\"Node 3\", style=\"filled\", fillcolor=\"#ffffff\", shape=hexagon, margin=0.05];\n7 [label=\"CONN_Select 2 of 4_SEL_Node 0\", style=\"filled\", fillcolor=\"#81D4FA\", shape=ellipse, margin=0.05];\n8 [label=\"CONN_Select 2 of 4_SEL_Node 1\", style=\"filled\", fillcolor=\"#81D4FA\", shape=ellipse, margin=0.05];\n9 [label=\"CONN_Select 2 of 4_SEL_Node 2\", style=\"filled\", fillcolor=\"#81D4FA\", shape=ellipse, margin=0.05];\n10 [label=\"CONN_Select 2 of 4_SEL_Node 3\", style=\"filled\", fillcolor=\"#81D4FA\", shape=ellipse, margin=0.05];\n11 [label=\"NonSel\", style=\"filled\", fillcolor=\"#ffffff\", shape=ellipse, margin=0.05];\n0 -> 1 [type=\"EdgeType.CONNECTS\", style=dashed, label=\"2\"];\n0 -> 2 [type=\"EdgeType.DERIVES\"];\n1 -> 3 [type=\"EdgeType.CONNECTS\", style=dashed, label=\"1\"];\n1 -> 4 [type=\"EdgeType.CONNECTS\", style=dashed, label=\"1\"];\n1 -> 5 [type=\"EdgeType.CONNECTS\", style=dashed, label=\"1\"];\n1 -> 6 [type=\"EdgeType.CONNECTS\", style=dashed, label=\"1\"];\n2 -> 7 [type=\"EdgeType.DERIVES\"];\n2 -> 8 [type=\"EdgeType.DERIVES\"];\n2 -> 9 [type=\"EdgeType.DERIVES\"];\n2 -> 10 [type=\"EdgeType.DERIVES\"];\n7 -> 11 [type=\"EdgeType.DERIVES\"];\n7 -> 3 [type=\"EdgeType.DERIVES\"];\n8 -> 11 [type=\"EdgeType.DERIVES\"];\n8 -> 4 [type=\"EdgeType.DERIVES\"];\n9 -> 11 [type=\"EdgeType.DERIVES\"];\n9 -> 5 [type=\"EdgeType.DERIVES\"];\n10 -> 11 [type=\"EdgeType.DERIVES\"];\n10 -> 6 [type=\"EdgeType.DERIVES\"];\n}\n"; // Export of the dot graph notation
#   var printDot = false; // Whether to print the dot instead of rendering
#   var printSvg = false; // Whether to print the SVG instead of showing the results
#   // Create viz-js instance and render to SVG
#   function doRender() {
#     if (printDot) {
#       var preEl = document.createElement('pre');
#       preEl.innerText = dot;
#       document.getElementById("f6bcef1d11c64203bfd6dd5d61422756").appendChild(preEl);
#     } else {
#       Viz.instance().then(function(viz) {
#         var tgtEl = document.getElementById("f6bcef1d11c64203bfd6dd5d61422756");
#         var svgElement = viz.renderSVGElement(dot);
#         if (printSvg) {
#           var preEl = document.createElement('pre');
#           preEl.innerText = svgElement.outerHTML;
#           tgtEl.appendChild(preEl);
#         } else {
#           tgtEl.appendChild(svgElement);
#         }
#       }).catch(function(e) {
#         console.log('RENDER ERROR', e, dot);
#         var preEl = document.createElement('pre');
#         preEl.innerText = 'RENDER ERROR: '+e.toString();
#         document.getElementById("f6bcef1d11c64203bfd6dd5d61422756").appendChild(preEl);
#         var preEl = document.createElement('pre');
#         preEl.innerText = dot;
#         document.getElementById("f6bcef1d11c64203bfd6dd5d61422756").appendChild(preEl);
#       });
#     }
#   }
#   // We may need to wait for loading to complete
#   function checkRender() {
#     if (typeof Viz === "undefined") { setTimeout(checkRender, 100+200*Math.random()); } else { doRender(); }
#   }
#   checkRender();
# })()
# </script>
# There are 20 ways to select 3 of 6.
# <div id="96900384cb8545d18dccb9367fc2b73f"></div>
# <script type="text/javascript" src="https://cdn.jsdelivr.net/npm/@viz-js/viz@3.8.0/lib/viz-standalone.js"></script>
# <script type="text/javascript">
# (function() {
#   var dot = "strict digraph {\nrankdir=LR;\ndpi=60;\nfontsize=20;\n0 [label=<<B>Select 3</B>>, style=\"filled,bold\", fillcolor=\"#ffffff\", shape=hexagon, margin=0.05];\n1 [label=\"Select 3 of 6\", style=\"filled\", fillcolor=\"#81D4FA\", shape=hexagon, margin=0.05];\n2 [label=\"Col\", style=\"filled\", fillcolor=\"#ffffff\", shape=ellipse, margin=0.05];\n3 [label=\"Node 0\", style=\"filled\", fillcolor=\"#ffffff\", shape=hexagon, margin=0.05];\n4 [label=\"Node 1\", style=\"filled\", fillcolor=\"#ffffff\", shape=hexagon, margin=0.05];\n5 [label=\"Node 2\", style=\"filled\", fillcolor=\"#ffffff\", shape=hexagon, margin=0.05];\n6 [label=\"Node 3\", style=\"filled\", fillcolor=\"#ffffff\", shape=hexagon, margin=0.05];\n7 [label=\"Node 4\", style=\"filled\", fillcolor=\"#ffffff\", shape=hexagon, margin=0.05];\n8 [label=\"Node 5\", style=\"filled\", fillcolor=\"#ffffff\", shape=hexagon, margin=0.05];\n9 [label=\"CONN_Select 3 of 6_SEL_Node 0\", style=\"filled\", fillcolor=\"#81D4FA\", shape=ellipse, margin=0.05];\n10 [label=\"CONN_Select 3 of 6_SEL_Node 1\", style=\"filled\", fillcolor=\"#81D4FA\", shape=ellipse, margin=0.05];\n11 [label=\"CONN_Select 3 of 6_SEL_Node 2\", style=\"filled\", fillcolor=\"#81D4FA\", shape=ellipse, margin=0.05];\n12 [label=\"CONN_Select 3 of 6_SEL_Node 3\", style=\"filled\", fillcolor=\"#81D4FA\", shape=ellipse, margin=0.05];\n13 [label=\"CONN_Select 3 of 6_SEL_Node 4\", style=\"filled\", fillcolor=\"#81D4FA\", shape=ellipse, margin=0.05];\n14 [label=\"CONN_Select 3 of 6_SEL_Node 5\", style=\"filled\", fillcolor=\"#81D4FA\", shape=ellipse, margin=0.05];\n15 [label=\"NonSel\", style=\"filled\", fillcolor=\"#ffffff\", shape=ellipse, margin=0.05];\n0 -> 1 [type=\"EdgeType.CONNECTS\", style=dashed, label=\"3\"];\n0 -> 2 [type=\"EdgeType.DERIVES\"];\n1 -> 3 [type=\"EdgeType.CONNECTS\", style=dashed, label=\"1\"];\n1 -> 4 [type=\"EdgeType.CONNECTS\", style=dashed, label=\"1\"];\n1 -> 5 [type=\"EdgeType.CONNECTS\", style=dashed, label=\"1\"];\n1 -> 6 [type=\"EdgeType.CONNECTS\", style=dashed, label=\"1\"];\n1 -> 7 [type=\"EdgeType.CONNECTS\", style=dashed, label=\"1\"];\n1 -> 8 [type=\"EdgeType.CONNECTS\", style=dashed, label=\"1\"];\n2 -> 9 [type=\"EdgeType.DERIVES\"];\n2 -> 10 [type=\"EdgeType.DERIVES\"];\n2 -> 11 [type=\"EdgeType.DERIVES\"];\n2 -> 12 [type=\"EdgeType.DERIVES\"];\n2 -> 13 [type=\"EdgeType.DERIVES\"];\n2 -> 14 [type=\"EdgeType.DERIVES\"];\n9 -> 15 [type=\"EdgeType.DERIVES\"];\n9 -> 3 [type=\"EdgeType.DERIVES\"];\n10 -> 15 [type=\"EdgeType.DERIVES\"];\n10 -> 4 [type=\"EdgeType.DERIVES\"];\n11 -> 15 [type=\"EdgeType.DERIVES\"];\n11 -> 5 [type=\"EdgeType.DERIVES\"];\n12 -> 15 [type=\"EdgeType.DERIVES\"];\n12 -> 6 [type=\"EdgeType.DERIVES\"];\n13 -> 15 [type=\"EdgeType.DERIVES\"];\n13 -> 7 [type=\"EdgeType.DERIVES\"];\n14 -> 15 [type=\"EdgeType.DERIVES\"];\n14 -> 8 [type=\"EdgeType.DERIVES\"];\n}\n"; // Export of the dot graph notation
#   var printDot = false; // Whether to print the dot instead of rendering
#   var printSvg = false; // Whether to print the SVG instead of showing the results
#   // Create viz-js instance and render to SVG
#   function doRender() {
#     if (printDot) {
#       var preEl = document.createElement('pre');
#       preEl.innerText = dot;
#       document.getElementById("96900384cb8545d18dccb9367fc2b73f").appendChild(preEl);
#     } else {
#       Viz.instance().then(function(viz) {
#         var tgtEl = document.getElementById("96900384cb8545d18dccb9367fc2b73f");
#         var svgElement = viz.renderSVGElement(dot);
#         if (printSvg) {
#           var preEl = document.createElement('pre');
#           preEl.innerText = svgElement.outerHTML;
#           tgtEl.appendChild(preEl);
#         } else {
#           tgtEl.appendChild(svgElement);
#         }
#       }).catch(function(e) {
#         console.log('RENDER ERROR', e, dot);
#         var preEl = document.createElement('pre');
#         preEl.innerText = 'RENDER ERROR: '+e.toString();
#         document.getElementById("96900384cb8545d18dccb9367fc2b73f").appendChild(preEl);
#         var preEl = document.createElement('pre');
#         preEl.innerText = dot;
#         document.getElementById("96900384cb8545d18dccb9367fc2b73f").appendChild(preEl);
#       });
#     }
#   }
#   // We may need to wait for loading to complete
#   function checkRender() {
#     if (typeof Viz === "undefined") { setTimeout(checkRender, 100+200*Math.random()); } else { doRender(); }
#   }
#   checkRender();
# })()
# </script>
# There are 70 ways to select 4 of 8.

# %% [markdown]
# This example shows that both the code to define the node selection scenario with advanced cardinality and the resulting DSG is more elegant when using connection choices with selection than when directly using selection choices.
#
# Additionally, the full power of connection choices is available. For example, multiple source nodes can derive and select target nodes, different number of connections may be established, and parallel connections can be used.
